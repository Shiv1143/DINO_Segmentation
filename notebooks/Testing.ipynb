# %%
pwd
# Out:
# '/content'

# %%
ls
# Out:
# drive/  sample_data/

# %%
cd drive/MyDrive/DINOv2_for_Semantic_Segmentation/
# Out:
# /content/drive/MyDrive/DINOv2_for_Semantic_Segmentation

# %%
ls
# Out:
# config.py    engine.py       infer_video.py  metrics.py  notebooks/  requirements.txt  train.py
# datasets.py  infer_image.py  input/          model.py    outputs/    temp.py           utils.py

# %%
pwd
# Out:
# '/content/drive/MyDrive/DINOv2_for_Semantic_Segmentation'

# %%
ls
# Out:
# config.py    infer_image.py  metrics.py  outputs/          temp.py
# datasets.py  infer_video.py  model.py    __pycache__/      train.py
# engine.py    input/          notebooks/  requirements.txt  utils.py

# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: torchvision==0.20.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 1)) (0.20.1+cu124)
# Collecting torchinfo==1.8.0 (from -r requirements.txt (line 2))
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: torch==2.5.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 3)) (2.5.1+cu124)
# Collecting albumentations==1.4.21 (from -r requirements.txt (line 4))
#   Downloading albumentations-1.4.21-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 5)) (4.11.0.86)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 6)) (4.67.1)
# Collecting matplotlib==3.9.2 (from -r requirements.txt (line 7))
#   Downloading matplotlib-3.9.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision==0.20.1->-r requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision==0.20.1->-r requirements.txt (line 1)) (11.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->-r requirements.txt (line 3)) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->-r requirements.txt (line 3)) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->-r requirements.txt (line 3)) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->-r requirements.txt (line 3)) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->-r requirements.txt (line 3)) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch==2.5.1->-r requirements.txt (line 3))
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch==2.5.1->-r requirements.txt (line 3))
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch==2.5.1->-r requirements.txt (line 3))
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch==2.5.1->-r requirements.txt (line 3))
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch==2.5.1->-r requirements.txt (line 3))
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch==2.5.1->-r requirements.txt (line 3))
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch==2.5.1->-r requirements.txt (line 3))
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch==2.5.1->-r requirements.txt (line 3))
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch==2.5.1->-r requirements.txt (line 3))
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->-r requirements.txt (line 3)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->-r requirements.txt (line 3)) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch==2.5.1->-r requirements.txt (line 3))
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->-r requirements.txt (line 3)) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->-r requirements.txt (line 3)) (1.13.1)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from albumentations==1.4.21->-r requirements.txt (line 4)) (1.13.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from albumentations==1.4.21->-r requirements.txt (line 4)) (6.0.2)
# Requirement already satisfied: pydantic>=2.7.0 in /usr/local/lib/python3.11/dist-packages (from albumentations==1.4.21->-r requirements.txt (line 4)) (2.10.6)
# Collecting albucore==0.0.20 (from albumentations==1.4.21->-r requirements.txt (line 4))
#   Downloading albucore-0.0.20-py3-none-any.whl.metadata (5.3 kB)
# Collecting eval-type-backport (from albumentations==1.4.21->-r requirements.txt (line 4))
#   Downloading eval_type_backport-0.2.2-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.11/dist-packages (from albumentations==1.4.21->-r requirements.txt (line 4)) (4.11.0.86)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.9.2->-r requirements.txt (line 7)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.9.2->-r requirements.txt (line 7)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.9.2->-r requirements.txt (line 7)) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.9.2->-r requirements.txt (line 7)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.9.2->-r requirements.txt (line 7)) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.9.2->-r requirements.txt (line 7)) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.9.2->-r requirements.txt (line 7)) (2.8.2)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.11/dist-packages (from albucore==0.0.20->albumentations==1.4.21->-r requirements.txt (line 4)) (3.12.2)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.11/dist-packages (from albucore==0.0.20->albumentations==1.4.21->-r requirements.txt (line 4)) (6.2.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch==2.5.1->-r requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.7.0->albumentations==1.4.21->-r requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.7.0->albumentations==1.4.21->-r requirements.txt (line 4)) (2.27.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib==3.9.2->-r requirements.txt (line 7)) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.5.1->-r requirements.txt (line 3)) (3.0.2)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Downloading albumentations-1.4.21-py3-none-any.whl (227 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.9/227.9 kB 9.5 MB/s eta 0:00:00
# Downloading matplotlib-3.9.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 94.5 MB/s eta 0:00:00
# Downloading albucore-0.0.20-py3-none-any.whl (12 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 129.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 95.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 65.4 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.0 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 39.7 MB/s eta 0:00:00
# Downloading eval_type_backport-0.2.2-py3-none-any.whl (5.8 kB)
# Installing collected packages: torchinfo, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, eval-type-backport, nvidia-cusparse-cu12, nvidia-cudnn-cu12, matplotlib, albucore, nvidia-cusolver-cu12, albumentations
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.0
#     Uninstalling matplotlib-3.10.0:
#       Successfully uninstalled matplotlib-3.10.0
#   Attempting uninstall: albucore
#     Found existing installation: albucore 0.0.23
#     Uninstalling albucore-0.0.23:
#       Successfully uninstalled albucore-0.0.23
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
#   Attempting uninstall: albumentations
#     Found existing installation: albumentations 2.0.5
#     Uninstalling albumentations-2.0.5:
#       Successfully uninstalled albumentations-2.0.5
# Successfully installed albucore-0.0.20 albumentations-1.4.21 eval-type-backport-0.2.2 matplotlib-3.9.2 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 torchinfo-1.8.0

# %%
# !python model.py
# Out:
# Downloading: "https://github.com/facebookresearch/dinov2/zipball/main" to /root/.cache/torch/hub/main.zip
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/swiglu_ffn.py:51: UserWarning: xFormers is not available (SwiGLU)
#   warnings.warn("xFormers is not available (SwiGLU)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/attention.py:33: UserWarning: xFormers is not available (Attention)
#   warnings.warn("xFormers is not available (Attention)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/block.py:40: UserWarning: xFormers is not available (Block)
#   warnings.warn("xFormers is not available (Block)")
# Downloading: "https://dl.fbaipublicfiles.com/dinov2/dinov2_vits14/dinov2_vits14_pretrain.pth" to /root/.cache/torch/hub/checkpoints/dinov2_vits14_pretrain.pth
# 100% 84.2M/84.2M [00:00<00:00, 95.8MB/s]
# =============================================================================================================================
# Layer (type (var_name))                            Input Shape               Output Shape              Param #
# =============================================================================================================================
# DINOv2Segmentation (DINOv2Segmentation)            [1, 3, 644, 644]          [1, 21, 46, 46]           --
# ├─Sequential (model)                               [1, 3, 644, 644]          [1, 21, 46, 46]           --
# │    └─DinoVisionTransformer (backbone)            [1, 3, 644, 644]          [1, 384, 46, 46]          526,848
# │    │    └─PatchEmbed (patch_embed)               [1, 3, 644, 644]          [1, 2116, 384]            (226,176)
# │    │    └─ModuleList (blocks)                    --                        --                        (21,302,784)
# │    │    └─LayerNorm (norm)                       [1, 2117, 384]            [1, 2117, 384]            (768)
# │    │    └─LayerNorm (norm)                       [1, 2117, 384]            [1, 2117, 384]            (recursive)
# │    │    └─LayerNorm (norm)                       [1, 2117, 384]            [1, 2117, 384]            (recursive)
# │    │    └─LayerNorm (norm)                       [1, 2117, 384]            [1, 2117, 384]            (recursive)
# │    └─BNHead (decode_head)                        [1, 384, 46, 46]          [1, 21, 46, 46]           --
# │    │    └─SyncBatchNorm (bn)                     [1, 1536, 46, 46]         [1, 1536, 46, 46]         3,072
# │    │    └─Conv2d (conv_seg)                      [1, 1536, 46, 46]         [1, 21, 46, 46]           32,277
# =============================================================================================================================
# Total params: 22,091,925
# Trainable params: 35,349
# Non-trainable params: 22,056,576
# Total mult-adds (Units.MEGABYTES): 568.19
# =============================================================================================================================
# Input size (MB): 4.98
# Forward/backward pass size (MB): 1073.41
# Params size (MB): 86.26
# Estimated Total Size (MB): 1164.64
# =============================================================================================================================

# %%
# !python train.py --lr 0.001 --batch 20 --imgsz 640 640 --epochs 65 --scheduler --scheduler-epochs 50
# Out:
# /usr/local/lib/python3.11/dist-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 2.0.7 (you have 1.4.21). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# Using cache found in /root/.cache/torch/hub/facebookresearch_dinov2_main
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/swiglu_ffn.py:51: UserWarning: xFormers is not available (SwiGLU)
#   warnings.warn("xFormers is not available (SwiGLU)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/attention.py:33: UserWarning: xFormers is not available (Attention)
#   warnings.warn("xFormers is not available (Attention)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/block.py:40: UserWarning: xFormers is not available (Block)
#   warnings.warn("xFormers is not available (Block)")
# Namespace(epochs=65, lr=0.001, batch=20, imgsz=[640, 640], scheduler=True, scheduler_epochs=[50])
# =============================================================================================================================
# Layer (type (var_name))                            Input Shape               Output Shape              Param #
# =============================================================================================================================
# DINOv2Segmentation (DINOv2Segmentation)            [1, 3, 644, 644]          [1, 2, 46, 46]            --
# ├─Sequential (model)                               [1, 3, 644, 644]          [1, 2, 46, 46]            --
# │    └─DinoVisionTransformer (backbone)            [1, 3, 644, 644]          [1, 384, 46, 46]          526,848
# │    │    └─PatchEmbed (patch_embed)               [1, 3, 644, 644]          [1, 2116, 384]            (226,176)
# │    │    └─ModuleList (blocks)                    --                        --                        (21,302,784)
# │    │    └─LayerNorm (norm)                       [1, 2117, 384]            [1, 2117, 384]            (768)
# │    │    └─LayerNorm (norm)                       [1, 2117, 384]            [1, 2117, 384]            (recursive)
# │    │    └─LayerNorm (norm)                       [1, 2117, 384]            [1, 2117, 384]            (recursive)
# │    │    └─LayerNorm (norm)                       [1, 2117, 384]            [1, 2117, 384]            (recursive)
# │    └─BNHead (decode_head)                        [1, 384, 46, 46]          [1, 2, 46, 46]            --
# │    │    └─SyncBatchNorm (bn)                     [1, 1536, 46, 46]         [1, 1536, 46, 46]         3,072
# │    │    └─Conv2d (conv_seg)                      [1, 1536, 46, 46]         [1, 2, 46, 46]            3,074
# =============================================================================================================================
# Total params: 22,062,722
# Trainable params: 6,146
# Non-trainable params: 22,056,576
# Total mult-adds (Units.MEGABYTES): 506.39
# =============================================================================================================================
# Input size (MB): 4.98
# Forward/backward pass size (MB): 1073.08
# Params size (MB): 86.14
# Estimated Total Size (MB): 1164.20
# =============================================================================================================================
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# EPOCH: 1
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:31<00:00,  3.96s/it]
# Validating
#  50% 1/2 [00:26<00:26, 26.21s/it][ WARN:0@63.106] global loadsave.cpp:848 imwrite_ Unsupported depth image for selected encoder is fallbacked to CV_8U.
# 100% 2/2 [00:27<00:00, 13.62s/it]
#
# Best validation loss: 0.35849733650684357
#
# Saving best model for epoch: 1
#
#
# Best validation IoU: 0.49251088299938983
#
# Saving best model for epoch: 1
#
# Train Epoch Loss: 0.5031, Train Epoch PixAcc: 0.6837, Train Epoch mIOU: 0.512563
# Valid Epoch Loss: 0.3585, Valid Epoch PixAcc: 0.5921 Valid Epoch mIOU: 0.492511
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 2
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:28<00:00,  3.59s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.55s/it]
#
# Best validation loss: 0.2698606699705124
#
# Saving best model for epoch: 2
#
#
# Best validation IoU: 0.5536081913723105
#
# Saving best model for epoch: 2
#
# Train Epoch Loss: 0.3497, Train Epoch PixAcc: 0.7959, Train Epoch mIOU: 0.655954
# Valid Epoch Loss: 0.2699, Valid Epoch PixAcc: 0.6251 Valid Epoch mIOU: 0.553608
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 3
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:29<00:00,  3.70s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.71s/it]
#
# Best validation loss: 0.2115052118897438
#
# Saving best model for epoch: 3
#
#
# Best validation IoU: 0.5773506473905122
#
# Saving best model for epoch: 3
#
# Train Epoch Loss: 0.3003, Train Epoch PixAcc: 0.8156, Train Epoch mIOU: 0.686498
# Valid Epoch Loss: 0.2115, Valid Epoch PixAcc: 0.6360 Valid Epoch mIOU: 0.577351
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 4
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:29<00:00,  3.67s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.60s/it]
#
# Best validation loss: 0.17361761629581451
#
# Saving best model for epoch: 4
#
#
# Best validation IoU: 0.5854416062866281
#
# Saving best model for epoch: 4
#
# Train Epoch Loss: 0.2572, Train Epoch PixAcc: 0.8222, Train Epoch mIOU: 0.697739
# Valid Epoch Loss: 0.1736, Valid Epoch PixAcc: 0.6395 Valid Epoch mIOU: 0.585442
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 5
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:29<00:00,  3.75s/it]
# Validating
# 100% 2/2 [00:06<00:00,  3.04s/it]
#
# Best validation loss: 0.14636153727769852
#
# Saving best model for epoch: 5
#
#
# Best validation IoU: 0.5897639429835161
#
# Saving best model for epoch: 5
#
# Train Epoch Loss: 0.2266, Train Epoch PixAcc: 0.8277, Train Epoch mIOU: 0.707493
# Valid Epoch Loss: 0.1464, Valid Epoch PixAcc: 0.6414 Valid Epoch mIOU: 0.589764
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 6
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:29<00:00,  3.63s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.66s/it]
#
# Best validation loss: 0.12370247766375542
#
# Saving best model for epoch: 6
#
#
# Best validation IoU: 0.59299513930637
#
# Saving best model for epoch: 6
#
# Train Epoch Loss: 0.1907, Train Epoch PixAcc: 0.8352, Train Epoch mIOU: 0.721715
# Valid Epoch Loss: 0.1237, Valid Epoch PixAcc: 0.6429 Valid Epoch mIOU: 0.592995
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 7
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:28<00:00,  3.54s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.79s/it]
#
# Best validation loss: 0.11566044390201569
#
# Saving best model for epoch: 7
#
#
# Best validation IoU: 0.594587680259684
#
# Saving best model for epoch: 7
#
# Train Epoch Loss: 0.1762, Train Epoch PixAcc: 0.8309, Train Epoch mIOU: 0.716151
# Valid Epoch Loss: 0.1157, Valid Epoch PixAcc: 0.6435 Valid Epoch mIOU: 0.594588
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 8
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:29<00:00,  3.72s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.74s/it]
#
# Best validation loss: 0.10095515847206116
#
# Saving best model for epoch: 8
#
#
# Best validation IoU: 0.5950403558901632
#
# Saving best model for epoch: 8
#
# Train Epoch Loss: 0.1649, Train Epoch PixAcc: 0.8358, Train Epoch mIOU: 0.721740
# Valid Epoch Loss: 0.1010, Valid Epoch PixAcc: 0.6439 Valid Epoch mIOU: 0.595040
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 9
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:29<00:00,  3.69s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.64s/it]
#
# Best validation loss: 0.0997994877398014
#
# Saving best model for epoch: 9
#
#
# Best validation IoU: 0.5955911025522495
#
# Saving best model for epoch: 9
#
# Train Epoch Loss: 0.1593, Train Epoch PixAcc: 0.8326, Train Epoch mIOU: 0.717899
# Valid Epoch Loss: 0.0998, Valid Epoch PixAcc: 0.6440 Valid Epoch mIOU: 0.595591
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 10
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:29<00:00,  3.74s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.96s/it]
#
# Best validation loss: 0.09358802437782288
#
# Saving best model for epoch: 10
#
#
# Best validation IoU: 0.5956868185896679
#
# Saving best model for epoch: 10
#
# Train Epoch Loss: 0.1541, Train Epoch PixAcc: 0.8373, Train Epoch mIOU: 0.724436
# Valid Epoch Loss: 0.0936, Valid Epoch PixAcc: 0.6441 Valid Epoch mIOU: 0.595687
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 11
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:30<00:00,  3.79s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.62s/it]
#
# Best validation loss: 0.09195126965641975
#
# Saving best model for epoch: 11
#
#
# Best validation IoU: 0.5964136804150075
#
# Saving best model for epoch: 11
#
# Train Epoch Loss: 0.1438, Train Epoch PixAcc: 0.8390, Train Epoch mIOU: 0.728235
# Valid Epoch Loss: 0.0920, Valid Epoch PixAcc: 0.6444 Valid Epoch mIOU: 0.596414
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 12
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:29<00:00,  3.69s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.82s/it]
#
# Best validation loss: 0.08907536789774895
#
# Saving best model for epoch: 12
#
#
# Best validation IoU: 0.5966991307632369
#
# Saving best model for epoch: 12
#
# Train Epoch Loss: 0.1487, Train Epoch PixAcc: 0.8316, Train Epoch mIOU: 0.710230
# Valid Epoch Loss: 0.0891, Valid Epoch PixAcc: 0.6445 Valid Epoch mIOU: 0.596699
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 13
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:29<00:00,  3.70s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.65s/it]
#
# Best validation loss: 0.0873185284435749
#
# Saving best model for epoch: 13
#
#
# Best validation IoU: 0.5972360939016853
#
# Saving best model for epoch: 13
#
# Train Epoch Loss: 0.1381, Train Epoch PixAcc: 0.8386, Train Epoch mIOU: 0.728720
# Valid Epoch Loss: 0.0873, Valid Epoch PixAcc: 0.6447 Valid Epoch mIOU: 0.597236
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 14
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:29<00:00,  3.65s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.62s/it]
#
# Best validation loss: 0.08474551886320114
#
# Saving best model for epoch: 14
#
#
# Best validation IoU: 0.5993991576079467
#
# Saving best model for epoch: 14
#
# Train Epoch Loss: 0.1335, Train Epoch PixAcc: 0.8393, Train Epoch mIOU: 0.730947
# Valid Epoch Loss: 0.0847, Valid Epoch PixAcc: 0.6454 Valid Epoch mIOU: 0.599399
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 15
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:29<00:00,  3.73s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.79s/it]
#
# Best validation loss: 0.08350342139601707
#
# Saving best model for epoch: 15
#
# Train Epoch Loss: 0.1324, Train Epoch PixAcc: 0.8401, Train Epoch mIOU: 0.733032
# Valid Epoch Loss: 0.0835, Valid Epoch PixAcc: 0.6454 Valid Epoch mIOU: 0.599368
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 16
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:29<00:00,  3.66s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.65s/it]
#
# Best validation loss: 0.08180861920118332
#
# Saving best model for epoch: 16
#
#
# Best validation IoU: 0.6010463457385303
#
# Saving best model for epoch: 16
#
# Train Epoch Loss: 0.1387, Train Epoch PixAcc: 0.8343, Train Epoch mIOU: 0.719589
# Valid Epoch Loss: 0.0818, Valid Epoch PixAcc: 0.6459 Valid Epoch mIOU: 0.601046
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 17
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:29<00:00,  3.65s/it]
# Validating
# 100% 2/2 [00:06<00:00,  3.05s/it]
# Train Epoch Loss: 0.1338, Train Epoch PixAcc: 0.8415, Train Epoch mIOU: 0.734648
# Valid Epoch Loss: 0.0826, Valid Epoch PixAcc: 0.6452 Valid Epoch mIOU: 0.598272
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 18
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:28<00:00,  3.57s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.62s/it]
#
# Best validation loss: 0.08096028864383698
#
# Saving best model for epoch: 18
#
#
# Best validation IoU: 0.6017199610533336
#
# Saving best model for epoch: 18
#
# Train Epoch Loss: 0.1347, Train Epoch PixAcc: 0.8357, Train Epoch mIOU: 0.723350
# Valid Epoch Loss: 0.0810, Valid Epoch PixAcc: 0.6461 Valid Epoch mIOU: 0.601720
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 19
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:29<00:00,  3.66s/it]
# Validating
# 100% 2/2 [00:06<00:00,  3.04s/it]
# Train Epoch Loss: 0.1316, Train Epoch PixAcc: 0.8413, Train Epoch mIOU: 0.735942
# Valid Epoch Loss: 0.0828, Valid Epoch PixAcc: 0.6450 Valid Epoch mIOU: 0.597559
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 20
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:28<00:00,  3.60s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.64s/it]
#
# Best validation loss: 0.08007939904928207
#
# Saving best model for epoch: 20
#
# Train Epoch Loss: 0.1280, Train Epoch PixAcc: 0.8425, Train Epoch mIOU: 0.739542
# Valid Epoch Loss: 0.0801, Valid Epoch PixAcc: 0.6460 Valid Epoch mIOU: 0.601374
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 21
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:28<00:00,  3.56s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.79s/it]
# Train Epoch Loss: 0.1260, Train Epoch PixAcc: 0.8432, Train Epoch mIOU: 0.742061
# Valid Epoch Loss: 0.0808, Valid Epoch PixAcc: 0.6453 Valid Epoch mIOU: 0.598298
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 22
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:28<00:00,  3.56s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.69s/it]
#
# Best validation loss: 0.07941317930817604
#
# Saving best model for epoch: 22
#
# Train Epoch Loss: 0.1310, Train Epoch PixAcc: 0.8386, Train Epoch mIOU: 0.726351
# Valid Epoch Loss: 0.0794, Valid Epoch PixAcc: 0.6458 Valid Epoch mIOU: 0.600552
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 23
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:28<00:00,  3.56s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.61s/it]
#
# Best validation loss: 0.07846485823392868
#
# Saving best model for epoch: 23
#
#
# Best validation IoU: 0.60263320214806
#
# Saving best model for epoch: 23
#
# Train Epoch Loss: 0.1270, Train Epoch PixAcc: 0.8409, Train Epoch mIOU: 0.733789
# Valid Epoch Loss: 0.0785, Valid Epoch PixAcc: 0.6463 Valid Epoch mIOU: 0.602633
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 24
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:29<00:00,  3.69s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.73s/it]
# Train Epoch Loss: 0.1324, Train Epoch PixAcc: 0.8401, Train Epoch mIOU: 0.733519
# Valid Epoch Loss: 0.0811, Valid Epoch PixAcc: 0.6449 Valid Epoch mIOU: 0.596890
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 25
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:27<00:00,  3.41s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.63s/it]
#
# Best validation loss: 0.07738960534334183
#
# Saving best model for epoch: 25
#
#
# Best validation IoU: 0.6029535141452399
#
# Saving best model for epoch: 25
#
# Train Epoch Loss: 0.1359, Train Epoch PixAcc: 0.8344, Train Epoch mIOU: 0.724137
# Valid Epoch Loss: 0.0774, Valid Epoch PixAcc: 0.6465 Valid Epoch mIOU: 0.602954
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 26
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:29<00:00,  3.66s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.75s/it]
# Train Epoch Loss: 0.1319, Train Epoch PixAcc: 0.8415, Train Epoch mIOU: 0.738102
# Valid Epoch Loss: 0.0781, Valid Epoch PixAcc: 0.6458 Valid Epoch mIOU: 0.600150
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 27
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:27<00:00,  3.41s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.65s/it]
# Train Epoch Loss: 0.1294, Train Epoch PixAcc: 0.8390, Train Epoch mIOU: 0.731528
# Valid Epoch Loss: 0.0775, Valid Epoch PixAcc: 0.6462 Valid Epoch mIOU: 0.601796
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 28
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:28<00:00,  3.59s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.71s/it]
# Train Epoch Loss: 0.1309, Train Epoch PixAcc: 0.8361, Train Epoch mIOU: 0.723383
# Valid Epoch Loss: 0.0805, Valid Epoch PixAcc: 0.6451 Valid Epoch mIOU: 0.597818
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 29
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:27<00:00,  3.43s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.64s/it]
# Train Epoch Loss: 0.1237, Train Epoch PixAcc: 0.8427, Train Epoch mIOU: 0.740465
# Valid Epoch Loss: 0.0778, Valid Epoch PixAcc: 0.6462 Valid Epoch mIOU: 0.601851
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 30
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:28<00:00,  3.58s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.69s/it]
#
# Best validation loss: 0.07648414745926857
#
# Saving best model for epoch: 30
#
# Train Epoch Loss: 0.1328, Train Epoch PixAcc: 0.8357, Train Epoch mIOU: 0.723001
# Valid Epoch Loss: 0.0765, Valid Epoch PixAcc: 0.6464 Valid Epoch mIOU: 0.602506
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 31
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:28<00:00,  3.53s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.62s/it]
# Train Epoch Loss: 0.1173, Train Epoch PixAcc: 0.8469, Train Epoch mIOU: 0.752270
# Valid Epoch Loss: 0.0771, Valid Epoch PixAcc: 0.6461 Valid Epoch mIOU: 0.601055
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 32
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:28<00:00,  3.62s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.70s/it]
#
# Best validation loss: 0.07614505290985107
#
# Saving best model for epoch: 32
#
# Train Epoch Loss: 0.1268, Train Epoch PixAcc: 0.8401, Train Epoch mIOU: 0.732534
# Valid Epoch Loss: 0.0761, Valid Epoch PixAcc: 0.6465 Valid Epoch mIOU: 0.602896
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 33
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:28<00:00,  3.56s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.67s/it]
# Train Epoch Loss: 0.1252, Train Epoch PixAcc: 0.8426, Train Epoch mIOU: 0.737865
# Valid Epoch Loss: 0.0773, Valid Epoch PixAcc: 0.6460 Valid Epoch mIOU: 0.600614
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 34
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:28<00:00,  3.53s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.79s/it]
#
# Best validation IoU: 0.6036837578271211
#
# Saving best model for epoch: 34
#
# Train Epoch Loss: 0.1212, Train Epoch PixAcc: 0.8435, Train Epoch mIOU: 0.745915
# Valid Epoch Loss: 0.0771, Valid Epoch PixAcc: 0.6465 Valid Epoch mIOU: 0.603684
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 35
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:28<00:00,  3.54s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.64s/it]
# Train Epoch Loss: 0.1284, Train Epoch PixAcc: 0.8407, Train Epoch mIOU: 0.734911
# Valid Epoch Loss: 0.0788, Valid Epoch PixAcc: 0.6454 Valid Epoch mIOU: 0.598657
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 36
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:28<00:00,  3.56s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.77s/it]
# Train Epoch Loss: 0.1288, Train Epoch PixAcc: 0.8373, Train Epoch mIOU: 0.730082
# Valid Epoch Loss: 0.0777, Valid Epoch PixAcc: 0.6461 Valid Epoch mIOU: 0.602050
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 37
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:27<00:00,  3.45s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.61s/it]
# Train Epoch Loss: 0.1284, Train Epoch PixAcc: 0.8402, Train Epoch mIOU: 0.733755
# Valid Epoch Loss: 0.0772, Valid Epoch PixAcc: 0.6459 Valid Epoch mIOU: 0.600412
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 38
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:28<00:00,  3.56s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.72s/it]
#
# Best validation loss: 0.07552977651357651
#
# Saving best model for epoch: 38
#
# Train Epoch Loss: 0.1310, Train Epoch PixAcc: 0.8357, Train Epoch mIOU: 0.724267
# Valid Epoch Loss: 0.0755, Valid Epoch PixAcc: 0.6466 Valid Epoch mIOU: 0.603259
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 39
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:28<00:00,  3.54s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.66s/it]
# Train Epoch Loss: 0.1264, Train Epoch PixAcc: 0.8422, Train Epoch mIOU: 0.740303
# Valid Epoch Loss: 0.0760, Valid Epoch PixAcc: 0.6463 Valid Epoch mIOU: 0.601911
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 40
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:28<00:00,  3.58s/it]
# Validating
# 100% 2/2 [00:06<00:00,  3.01s/it]
# Train Epoch Loss: 0.1249, Train Epoch PixAcc: 0.8424, Train Epoch mIOU: 0.737279
# Valid Epoch Loss: 0.0763, Valid Epoch PixAcc: 0.6463 Valid Epoch mIOU: 0.602560
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 41
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:28<00:00,  3.53s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.59s/it]
# Train Epoch Loss: 0.1246, Train Epoch PixAcc: 0.8411, Train Epoch mIOU: 0.735060
# Valid Epoch Loss: 0.0778, Valid Epoch PixAcc: 0.6456 Valid Epoch mIOU: 0.599122
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 42
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:27<00:00,  3.45s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.57s/it]
# Train Epoch Loss: 0.1270, Train Epoch PixAcc: 0.8387, Train Epoch mIOU: 0.728034
# Valid Epoch Loss: 0.0758, Valid Epoch PixAcc: 0.6465 Valid Epoch mIOU: 0.602764
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 43
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:25<00:00,  3.23s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.70s/it]
#
# Best validation loss: 0.07497864216566086
#
# Saving best model for epoch: 43
#
#
# Best validation IoU: 0.6043484619489378
#
# Saving best model for epoch: 43
#
# Train Epoch Loss: 0.1205, Train Epoch PixAcc: 0.8438, Train Epoch mIOU: 0.744401
# Valid Epoch Loss: 0.0750, Valid Epoch PixAcc: 0.6468 Valid Epoch mIOU: 0.604348
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 44
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:28<00:00,  3.52s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.58s/it]
# Train Epoch Loss: 0.1236, Train Epoch PixAcc: 0.8423, Train Epoch mIOU: 0.739059
# Valid Epoch Loss: 0.0757, Valid Epoch PixAcc: 0.6462 Valid Epoch mIOU: 0.601526
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 45
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:26<00:00,  3.36s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.77s/it]
# Train Epoch Loss: 0.1245, Train Epoch PixAcc: 0.8404, Train Epoch mIOU: 0.732680
# Valid Epoch Loss: 0.0759, Valid Epoch PixAcc: 0.6463 Valid Epoch mIOU: 0.602009
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 46
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:27<00:00,  3.39s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.53s/it]
#
# Best validation loss: 0.07482588291168213
#
# Saving best model for epoch: 46
#
# Train Epoch Loss: 0.1235, Train Epoch PixAcc: 0.8427, Train Epoch mIOU: 0.738012
# Valid Epoch Loss: 0.0748, Valid Epoch PixAcc: 0.6467 Valid Epoch mIOU: 0.603172
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 47
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:27<00:00,  3.48s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.68s/it]
# Train Epoch Loss: 0.1221, Train Epoch PixAcc: 0.8414, Train Epoch mIOU: 0.733966
# Valid Epoch Loss: 0.0753, Valid Epoch PixAcc: 0.6464 Valid Epoch mIOU: 0.602276
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 48
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:26<00:00,  3.29s/it]
# Validating
# 100% 2/2 [00:04<00:00,  2.49s/it]
#
# Best validation loss: 0.07428925856947899
#
# Saving best model for epoch: 48
#
#
# Best validation IoU: 0.6043725681163297
#
# Saving best model for epoch: 48
#
# Train Epoch Loss: 0.1183, Train Epoch PixAcc: 0.8466, Train Epoch mIOU: 0.752067
# Valid Epoch Loss: 0.0743, Valid Epoch PixAcc: 0.6469 Valid Epoch mIOU: 0.604373
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 49
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:27<00:00,  3.50s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.58s/it]
# Train Epoch Loss: 0.1261, Train Epoch PixAcc: 0.8421, Train Epoch mIOU: 0.737136
# Valid Epoch Loss: 0.0749, Valid Epoch PixAcc: 0.6467 Valid Epoch mIOU: 0.603732
# LR for next epoch: [0.001]
# --------------------------------------------------
# EPOCH: 50
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:26<00:00,  3.29s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.65s/it]
# Train Epoch Loss: 0.1220, Train Epoch PixAcc: 0.8416, Train Epoch mIOU: 0.737457
# Valid Epoch Loss: 0.0758, Valid Epoch PixAcc: 0.6463 Valid Epoch mIOU: 0.601973
# LR for next epoch: [0.0001]
# --------------------------------------------------
# EPOCH: 51
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:26<00:00,  3.36s/it]
# Validating
# 100% 2/2 [00:04<00:00,  2.50s/it]
# Train Epoch Loss: 0.1250, Train Epoch PixAcc: 0.8435, Train Epoch mIOU: 0.741690
# Valid Epoch Loss: 0.0756, Valid Epoch PixAcc: 0.6463 Valid Epoch mIOU: 0.602117
# LR for next epoch: [0.0001]
# --------------------------------------------------
# EPOCH: 52
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:27<00:00,  3.44s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.62s/it]
# Train Epoch Loss: 0.1241, Train Epoch PixAcc: 0.8430, Train Epoch mIOU: 0.739658
# Valid Epoch Loss: 0.0754, Valid Epoch PixAcc: 0.6464 Valid Epoch mIOU: 0.602359
# LR for next epoch: [0.0001]
# --------------------------------------------------
# EPOCH: 53
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:26<00:00,  3.30s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.54s/it]
# Train Epoch Loss: 0.1230, Train Epoch PixAcc: 0.8415, Train Epoch mIOU: 0.735671
# Valid Epoch Loss: 0.0752, Valid Epoch PixAcc: 0.6465 Valid Epoch mIOU: 0.602888
# LR for next epoch: [0.0001]
# --------------------------------------------------
# EPOCH: 54
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:27<00:00,  3.47s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.61s/it]
# Train Epoch Loss: 0.1200, Train Epoch PixAcc: 0.8436, Train Epoch mIOU: 0.744673
# Valid Epoch Loss: 0.0750, Valid Epoch PixAcc: 0.6465 Valid Epoch mIOU: 0.602662
# LR for next epoch: [0.0001]
# --------------------------------------------------
# EPOCH: 55
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:27<00:00,  3.44s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.72s/it]
# Train Epoch Loss: 0.1243, Train Epoch PixAcc: 0.8407, Train Epoch mIOU: 0.734419
# Valid Epoch Loss: 0.0746, Valid Epoch PixAcc: 0.6467 Valid Epoch mIOU: 0.603385
# LR for next epoch: [0.0001]
# --------------------------------------------------
# EPOCH: 56
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:27<00:00,  3.38s/it]
# Validating
# 100% 2/2 [00:04<00:00,  2.46s/it]
# Train Epoch Loss: 0.1227, Train Epoch PixAcc: 0.8431, Train Epoch mIOU: 0.741598
# Valid Epoch Loss: 0.0745, Valid Epoch PixAcc: 0.6467 Valid Epoch mIOU: 0.603389
# LR for next epoch: [0.0001]
# --------------------------------------------------
# EPOCH: 57
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:27<00:00,  3.43s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.64s/it]
#
# Best validation loss: 0.07426104322075844
#
# Saving best model for epoch: 57
#
# Train Epoch Loss: 0.1176, Train Epoch PixAcc: 0.8446, Train Epoch mIOU: 0.745165
# Valid Epoch Loss: 0.0743, Valid Epoch PixAcc: 0.6468 Valid Epoch mIOU: 0.603832
# LR for next epoch: [0.0001]
# --------------------------------------------------
# EPOCH: 58
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:27<00:00,  3.45s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.86s/it]
#
# Best validation loss: 0.0741133987903595
#
# Saving best model for epoch: 58
#
# Train Epoch Loss: 0.1209, Train Epoch PixAcc: 0.8426, Train Epoch mIOU: 0.739653
# Valid Epoch Loss: 0.0741, Valid Epoch PixAcc: 0.6468 Valid Epoch mIOU: 0.603711
# LR for next epoch: [0.0001]
# --------------------------------------------------
# EPOCH: 59
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:27<00:00,  3.48s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.65s/it]
# Train Epoch Loss: 0.1209, Train Epoch PixAcc: 0.8411, Train Epoch mIOU: 0.734495
# Valid Epoch Loss: 0.0742, Valid Epoch PixAcc: 0.6468 Valid Epoch mIOU: 0.603926
# LR for next epoch: [0.0001]
# --------------------------------------------------
# EPOCH: 60
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:27<00:00,  3.42s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.61s/it]
# Train Epoch Loss: 0.1158, Train Epoch PixAcc: 0.8439, Train Epoch mIOU: 0.743630
# Valid Epoch Loss: 0.0743, Valid Epoch PixAcc: 0.6468 Valid Epoch mIOU: 0.603701
# LR for next epoch: [0.0001]
# --------------------------------------------------
# EPOCH: 61
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:26<00:00,  3.27s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.57s/it]
# Train Epoch Loss: 0.1254, Train Epoch PixAcc: 0.8407, Train Epoch mIOU: 0.731542
# Valid Epoch Loss: 0.0744, Valid Epoch PixAcc: 0.6468 Valid Epoch mIOU: 0.604053
# LR for next epoch: [0.0001]
# --------------------------------------------------
# EPOCH: 62
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:27<00:00,  3.39s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.53s/it]
# Train Epoch Loss: 0.1144, Train Epoch PixAcc: 0.8468, Train Epoch mIOU: 0.751127
# Valid Epoch Loss: 0.0745, Valid Epoch PixAcc: 0.6468 Valid Epoch mIOU: 0.603822
# LR for next epoch: [0.0001]
# --------------------------------------------------
# EPOCH: 63
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:27<00:00,  3.40s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.77s/it]
# Train Epoch Loss: 0.1197, Train Epoch PixAcc: 0.8423, Train Epoch mIOU: 0.738052
# Valid Epoch Loss: 0.0745, Valid Epoch PixAcc: 0.6467 Valid Epoch mIOU: 0.603261
# LR for next epoch: [0.0001]
# --------------------------------------------------
# EPOCH: 64
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:26<00:00,  3.33s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.52s/it]
# Train Epoch Loss: 0.1217, Train Epoch PixAcc: 0.8406, Train Epoch mIOU: 0.731680
# Valid Epoch Loss: 0.0746, Valid Epoch PixAcc: 0.6466 Valid Epoch mIOU: 0.603191
# LR for next epoch: [0.0001]
# --------------------------------------------------
# EPOCH: 65
# Training
#   0% 0/8 [00:00<?, ?it/s]  0% 0/8 [00:00<?, ?it/s]
# 100% 8/8 [00:27<00:00,  3.42s/it]
# Validating
# 100% 2/2 [00:05<00:00,  2.61s/it]
# Train Epoch Loss: 0.1209, Train Epoch PixAcc: 0.8412, Train Epoch mIOU: 0.734806
# Valid Epoch Loss: 0.0746, Valid Epoch PixAcc: 0.6467 Valid Epoch mIOU: 0.603325
# LR for next epoch: [0.0001]
# --------------------------------------------------
# TRAINING COMPLETE

# %%
# !python infer_image.py --imgsz 640 640 --model outputs/best_model_iou.pth
# Out:
# Using cache found in /root/.cache/torch/hub/facebookresearch_dinov2_main
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/swiglu_ffn.py:51: UserWarning: xFormers is not available (SwiGLU)
#   warnings.warn("xFormers is not available (SwiGLU)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/attention.py:33: UserWarning: xFormers is not available (Attention)
#   warnings.warn("xFormers is not available (Attention)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/block.py:40: UserWarning: xFormers is not available (Block)
#   warnings.warn("xFormers is not available (Block)")
# /usr/local/lib/python3.11/dist-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 2.0.7 (you have 1.4.21). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# /content/drive/MyDrive/DINOv2_for_Semantic_Segmentation/infer_image.py:46: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(args.model)
# save infered image
# save infered image
# save infered image
